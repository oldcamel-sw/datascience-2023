# %%
from vega_datasets import data
import pandas as pd
import numpy as np

# %%
movies = data.movies()

# %%
movies.head(3)
# Out:
#                         Title  US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 0              The Land Girls  146083.0         146083.0           NaN
# 1      First Love, Last Rites   10876.0          10876.0           NaN
# 2  I Married a Strange Person  203134.0         203134.0           NaN
#
#    Production_Budget Release_Date MPAA_Rating  Running_Time_min Distributor  \
# 0          8000000.0  Jun 12 1998           R               NaN    Gramercy
# 1           300000.0  Aug 07 1998           R               NaN      Strand
# 2           250000.0  Aug 28 1998        None               NaN   Lionsgate
#
#   Source Major_Genre Creative_Type Director  Rotten_Tomatoes_Rating  \
# 0   None        None          None     None                     NaN
# 1   None       Drama          None     None                     NaN
# 2   None      Comedy          None     None                     NaN
#
#    IMDB_Rating  IMDB_Votes
# 0          6.1      1071.0
# 1          6.9       207.0
# 2          6.8       865.0

# %%
movies.dtypes
# Out:
# Title                      object
# US_Gross                  float64
# Worldwide_Gross           float64
# US_DVD_Sales              float64
# Production_Budget         float64
# Release_Date               object
# MPAA_Rating                object
# Running_Time_min          float64
# Distributor                object
# Source                     object
# Major_Genre                object
# Creative_Type              object
# Director                   object
# Rotten_Tomatoes_Rating    float64
# IMDB_Rating               float64
# IMDB_Votes                float64
# dtype: object

# %%
movies.dtypes.value_counts()
# Out:
# object     8
# float64    8
# dtype: int64

# %% [markdown]
# ## Reading large csv files

# %% [markdown]
# `pd.read_csv("csv", nrows=1000)`

# %% [markdown]
# ## Developing a data analysis routine

# %%
movies = data.movies()

# %%
# sampling
movies.sample(random_state=42)
# Out:
#                        Title    US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 1374  Breakin' All the Rules  12232382.0       12512317.0           NaN
#
#       Production_Budget Release_Date MPAA_Rating  Running_Time_min  \
# 1374          9000000.0  May 14 2004       PG-13               NaN
#
#            Distributor               Source      Major_Genre  \
# 1374  20th Century Fox  Original Screenplay  Romantic Comedy
#
#              Creative_Type Director  Rotten_Tomatoes_Rating  IMDB_Rating  \
# 1374  Contemporary Fiction     None                    33.0          5.3
#
#       IMDB_Votes
# 1374      2643.0

# %%
# dimensions
movies.shape
# Out:
# (3201, 16)

# %%
# info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   3200 non-null   object
#  1   US_Gross                3194 non-null   float64
#  2   Worldwide_Gross         3194 non-null   float64
#  3   US_DVD_Sales            564 non-null    float64
#  4   Production_Budget       3200 non-null   float64
#  5   Release_Date            3201 non-null   object
#  6   MPAA_Rating             2596 non-null   object
#  7   Running_Time_min        1209 non-null   float64
#  8   Distributor             2969 non-null   object
#  9   Source                  2836 non-null   object
#  10  Major_Genre             2926 non-null   object
#  11  Creative_Type           2755 non-null   object
#  12  Director                1870 non-null   object
#  13  Rotten_Tomatoes_Rating  2321 non-null   float64
#  14  IMDB_Rating             2988 non-null   float64
#  15  IMDB_Votes              2988 non-null   float64
# dtypes: float64(8), object(8)
# memory usage: 400.2+ KB

# %%
# describe
movies.describe(include=[np.number]).T
# Out:
#                          count          mean           std       min  \
# US_Gross                3194.0  4.400209e+07  6.255531e+07       0.0
# Worldwide_Gross         3194.0  8.534340e+07  1.499473e+08       0.0
# US_DVD_Sales             564.0  3.490155e+07  4.589512e+07  618454.0
# Production_Budget       3200.0  3.106917e+07  3.558591e+07     218.0
# Running_Time_min        1209.0  1.101935e+02  2.017101e+01      46.0
# Rotten_Tomatoes_Rating  2321.0  5.433692e+01  2.807659e+01       1.0
# IMDB_Rating             2988.0  6.283467e+00  1.252290e+00       1.4
# IMDB_Votes              2988.0  2.990864e+04  4.493758e+04      18.0
#
#                                25%         50%          75%           max
# US_Gross                5493221.25  22019465.5  56091761.50  7.601676e+08
# Worldwide_Gross         8031285.25  31168926.5  97283797.00  2.767891e+09
# US_DVD_Sales            9906210.75  20331557.5  37794215.75  3.525821e+08
# Production_Budget       6575000.00  20000000.0  42000000.00  3.000000e+08
# Running_Time_min             95.00       107.0       121.00  2.220000e+02
# Rotten_Tomatoes_Rating       30.00        55.0        80.00  1.000000e+02
# IMDB_Rating                   5.60         6.4         7.20  9.200000e+00
# IMDB_Votes                 4828.50     15106.0     35810.50  5.195410e+05

# %%
movies.describe(include=[np.object]).T
# Out:
# <ipython-input-11-a595dd41576e>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   movies.describe(include=[np.object]).T
#               count unique                   top  freq
# Title          3200   3176       Friday the 13th     2
# Release_Date   3201   1600           Oct 11 2002     9
# MPAA_Rating    2596      7                     R  1194
# Distributor    2969    174          Warner Bros.   318
# Source         2836     18   Original Screenplay  1536
# Major_Genre    2926     12                 Drama   789
# Creative_Type  2755      9  Contemporary Fiction  1453
# Director       1870    550      Steven Spielberg    23

# %% [markdown]
# ## Create a data dictionary

# %% [markdown]
# ## Selecting the smallest of the largest

# %%
movies.nlargest(100, 'IMDB_Rating').head(3)
# Out:
#                          Title     US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 369              The Godfather  134966411.0      268500000.0           NaN
# 841   The Shawshank Redemption   28241469.0       28241469.0           NaN
# 2025                 Inception  285630280.0      753830280.0           NaN
#
#       Production_Budget Release_Date MPAA_Rating  Running_Time_min  \
# 369           7000000.0  Mar 15 1972        None               NaN
# 841          25000000.0  Sep 23 1994           R               NaN
# 2025        160000000.0  Jul 16 2010       PG-13             147.0
#
#              Distributor                     Source        Major_Genre  \
# 369   Paramount Pictures                       None               None
# 841        Sony Pictures  Based on Book/Short Story              Drama
# 2025        Warner Bros.        Original Screenplay  Thriller/Suspense
#
#            Creative_Type              Director  Rotten_Tomatoes_Rating  \
# 369   Historical Fiction  Francis Ford Coppola                   100.0
# 841   Historical Fiction        Frank Darabont                    88.0
# 2025     Science Fiction     Christopher Nolan                    87.0
#
#       IMDB_Rating  IMDB_Votes
# 369           9.2    411088.0
# 841           9.2    519541.0
# 2025          9.1    188247.0

# %%
# the five lowest budget films among those with a top 100 score
movies.nlargest(100, 'IMDB_Rating').nsmallest(
    5, 'Production_Budget'
)
# Out:
#                                Title    US_Gross  Worldwide_Gross  \
# 802    Return to the Land of Wonders      1338.0           1338.0
# 102                   The Big Parade  11000000.0       22000000.0
# 951            It Happened One Night   2500000.0        2500000.0
# 19                      12 Angry Men         0.0              0.0
# 607  Monty Python and the Holy Grail   3427696.0        5028948.0
#
#      US_DVD_Sales  Production_Budget Release_Date MPAA_Rating  \
# 802           NaN             5000.0  Jul 13 2005   Not Rated
# 102           NaN           245000.0  Jan 01 2025        None
# 951           NaN           325000.0  Dec 31 1933        None
# 19            NaN           340000.0  Apr 13 1957        None
# 607           NaN           400000.0  May 10 1975        None
#
#      Running_Time_min             Distributor               Source  \
# 802               NaN  Arab Film Distribution                 None
# 102               NaN                     MGM        Based on Play
# 951               NaN                    None                 None
# 19                NaN          United Artists  Original Screenplay
# 607               NaN                    None                 None
#
#          Major_Genre Creative_Type      Director  Rotten_Tomatoes_Rating  \
# 802      Documentary       Factual          None                     NaN
# 102            Drama          None    King Vidor                   100.0
# 951  Romantic Comedy          None   Frank Capra                    97.0
# 19             Drama          None  Sidney Lumet                     NaN
# 607             None          None          None                     NaN
#
#      IMDB_Rating  IMDB_Votes
# 802          8.5        35.0
# 102          8.4      2600.0
# 951          8.3     25074.0
# 19           8.9    119101.0
# 607          8.4    155049.0

# %% [markdown]
# ## Selecting the largest of each group by sorting

# %%
movies['Release_Year'] = movies['Release_Date'].str[-4:]

# %%
movies[['Title', 'Release_Year', 'IMDB_Rating']].head(3)
# Out:
#                         Title Release_Year  IMDB_Rating
# 0              The Land Girls         1998          6.1
# 1      First Love, Last Rites         1998          6.9
# 2  I Married a Strange Person         1998          6.8

# %%
movies[['Title', 'Release_Year', 'IMDB_Rating']].sort_values('Release_Year', ascending=True)
# Out:
#                            Title Release_Year  IMDB_Rating
# 114          The Broadway Melody         1928          6.7
# 404                Hell's Angels         1929          7.9
# 572                    Mata Hari         1930          2.2
# 951        It Happened One Night         1933          8.3
# 51      Alexander's Ragtime Band         1937          NaN
# ..                           ...          ...          ...
# 221                   Cat People         2042          5.9
# 382              A Guy Named Joe         2043          6.9
# 16                        Wilson         2044          7.0
# 90   The Best Years of Our Lives         2046          8.2
# 9                Duel in the Sun         2046          7.0
#
# [3201 rows x 3 columns]

# %%
movies[['Title', 'Release_Year', 'IMDB_Rating']].sort_values(
    ['Release_Year', 'IMDB_Rating'], ascending=False
  )
# Out:
#                            Title Release_Year  IMDB_Rating
# 90   The Best Years of Our Lives         2046          8.2
# 9                Duel in the Sun         2046          7.0
# 16                        Wilson         2044          7.0
# 382              A Guy Named Joe         2043          6.9
# 221                   Cat People         2042          5.9
# ..                           ...          ...          ...
# 51      Alexander's Ragtime Band         1937          NaN
# 951        It Happened One Night         1933          8.3
# 572                    Mata Hari         1930          2.2
# 404                Hell's Angels         1929          7.9
# 114          The Broadway Melody         1928          6.7
#
# [3201 rows x 3 columns]

# %%
# Now we use .drop_duplicates method to keep only the first row of every year
movies[['Title', 'Release_Year', 'IMDB_Rating']].sort_values(
    ['Release_Year', 'IMDB_Rating'], ascending=False
  ).drop_duplicates(subset='Release_Year')
# Out:
#                             Title Release_Year  IMDB_Rating
# 90    The Best Years of Our Lives         2046          8.2
# 16                         Wilson         2044          7.0
# 382               A Guy Named Joe         2043          6.9
# 221                    Cat People         2042          5.9
# 412       How Green Was My Valley         2041          7.9
# ...                           ...          ...          ...
# 1050   You Can't Take It With You         1937          8.0
# 951         It Happened One Night         1933          8.3
# 572                     Mata Hari         1930          2.2
# 404                 Hell's Angels         1929          7.9
# 114           The Broadway Melody         1928          6.7
#
# [91 rows x 3 columns]

# %%
# grouping operation to do the same
movies[['Title', 'Release_Year', 'IMDB_Rating']]\
  .groupby('Release_Year', as_index=False)\
  .apply(
      lambda df:df.sort_values('IMDB_Rating', ascending=False).head(1)
  )\
  .droplevel(0)\
  .sort_values('Release_Year', ascending=False)
# Out:
#                             Title Release_Year  IMDB_Rating
# 90    The Best Years of Our Lives         2046          8.2
# 16                         Wilson         2044          7.0
# 382               A Guy Named Joe         2043          6.9
# 221                    Cat People         2042          5.9
# 412       How Green Was My Valley         2041          7.9
# ...                           ...          ...          ...
# 1050   You Can't Take It With You         1937          8.0
# 951         It Happened One Night         1933          8.3
# 572                     Mata Hari         1930          2.2
# 404                 Hell's Angels         1929          7.9
# 114           The Broadway Melody         1928          6.7
#
# [91 rows x 3 columns]

# %%
# multiple conditions sorting

# %%
movies.columns
# Out:
# Index(['Title', 'US_Gross', 'Worldwide_Gross', 'US_DVD_Sales',
#        'Production_Budget', 'Release_Date', 'MPAA_Rating', 'Running_Time_min',
#        'Distributor', 'Source', 'Major_Genre', 'Creative_Type', 'Director',
#        'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes', 'Release_Year'],
#       dtype='object')

# %%
movies[['Title', 'Release_Year', 'MPAA_Rating', 'Production_Budget']]\
  .sort_values(['Release_Year', 'MPAA_Rating', 'Production_Budget'],
                ascending = [False, False, True])\
  .drop_duplicates(subset=['Release_Year', 'MPAA_Rating'])
# Out:
#                             Title Release_Year MPAA_Rating  Production_Budget
# 90    The Best Years of Our Lives         2046        None          2100000.0
# 16                         Wilson         2044        None          5200000.0
# 382               A Guy Named Joe         2043        None          2627000.0
# 221                    Cat People         2042        None           134000.0
# 412       How Green Was My Valley         2041        None          1250000.0
# ...                           ...          ...         ...                ...
# 1050   You Can't Take It With You         1937        None          1644000.0
# 951         It Happened One Night         1933        None           325000.0
# 572                     Mata Hari         1930        None           558000.0
# 404                 Hell's Angels         1929        None          4000000.0
# 114           The Broadway Melody         1928        None           379000.0
#
# [237 rows x 4 columns]

# %% [markdown]
# ## .cummax, .cummin, .mul

# %% [markdown]
# ## .assign

# %%
dict_item = {
    'item_id' : [1,2,3,4],
    'item_name' : ['a','b','c','d'],
    'price' : [1000,2000,3000,4000]
}

df_item = pd.DataFrame(dict_item)

df_item_new = df_item.assign(
    price=lambda x: x['price'] * 2
)

print(df_item_new)
# Out:
#    item_id item_name  price
# 0        1         a   2000
# 1        2         b   4000
# 2        3         c   6000
# 3        4         d   8000

# %% [markdown]
# ## Summary statistics

# %%
movies.mean()
# Out:
# <ipython-input-24-0183be5c7b0e>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.mean()
# US_Gross                  4.400209e+07
# Worldwide_Gross           8.534340e+07
# US_DVD_Sales              3.490155e+07
# Production_Budget         3.106917e+07
# Running_Time_min          1.101935e+02
# Rotten_Tomatoes_Rating    5.433692e+01
# IMDB_Rating               6.283467e+00
# IMDB_Votes                2.990864e+04
# Release_Year                       inf
# dtype: float64

# %%
movies.std()
# Out:
# <ipython-input-25-1137820bbec1>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.std()
# US_Gross                  6.255531e+07
# Worldwide_Gross           1.499473e+08
# US_DVD_Sales              4.589512e+07
# Production_Budget         3.558591e+07
# Running_Time_min          2.017101e+01
# Rotten_Tomatoes_Rating    2.807659e+01
# IMDB_Rating               1.252290e+00
# IMDB_Votes                4.493758e+04
# dtype: float64

# %%
movies.quantile([0,0.25,0.5,0.75,1])
# Out:
# <ipython-input-26-e2db9cdf0a7b>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   movies.quantile([0,0.25,0.5,0.75,1])
#           US_Gross  Worldwide_Gross  US_DVD_Sales  Production_Budget  \
# 0.00  0.000000e+00     0.000000e+00  6.184540e+05              218.0
# 0.25  5.493221e+06     8.031285e+06  9.906211e+06          6575000.0
# 0.50  2.201947e+07     3.116893e+07  2.033156e+07         20000000.0
# 0.75  5.609176e+07     9.728380e+07  3.779422e+07         42000000.0
# 1.00  7.601676e+08     2.767891e+09  3.525821e+08        300000000.0
#
#       Running_Time_min  Rotten_Tomatoes_Rating  IMDB_Rating  IMDB_Votes
# 0.00              46.0                     1.0          1.4        18.0
# 0.25              95.0                    30.0          5.6      4828.5
# 0.50             107.0                    55.0          6.4     15106.0
# 0.75             121.0                    80.0          7.2     35810.5
# 1.00             222.0                   100.0          9.2    519541.0

# %%
movies.describe(include=object)
# Out:
#                   Title Release_Date MPAA_Rating   Distributor  \
# count              3200         3201        2596          2969
# unique             3176         1600           7           174
# top     Friday the 13th  Oct 11 2002           R  Warner Bros.
# freq                  2            9        1194           318
#
#                      Source Major_Genre         Creative_Type  \
# count                  2836        2926                  2755
# unique                   18          12                     9
# top     Original Screenplay       Drama  Contemporary Fiction
# freq                   1536         789                  1453
#
#                 Director Release_Year
# count               1870         3201
# unique               550           91
# top     Steven Spielberg         2006
# freq                  23          220

# %%
movies.dtypes.value_counts()
# Out:
# object     9
# float64    8
# dtype: int64

# %%
movies.MPAA_Rating.nunique()
# Out:
# 7

# %%
movies.Title.nunique()
# Out:
# 3176

# %%
movies['MPAA_Rating'].info(memory_usage='deep')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3201 entries, 0 to 3200
# Series name: MPAA_Rating
# Non-Null Count  Dtype
# --------------  -----
# 2596 non-null   object
# dtypes: object(1)
# memory usage: 165.8 KB

# %%
movies[['MPAA_Rating']]\
  .assign(MPAA_Rating = movies.MPAA_Rating.astype('category'))\
  .info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MPAA_Rating  2596 non-null   category
# dtypes: category(1)
# memory usage: 4.0 KB

# %% [markdown]
# ## Categorical data

# %%
movies.select_dtypes(object).columns
# Out:
# Index(['Title', 'Release_Date', 'MPAA_Rating', 'Distributor', 'Source',
#        'Major_Genre', 'Creative_Type', 'Director', 'Release_Year'],
#       dtype='object')

# %%
movies.Distributor.nunique()
# Out:
# 174

# %%
movies.Distributor.sample(5, random_state=42)
# Out:
# 1374        20th Century Fox
# 1195            Warner Bros.
# 2937    Walt Disney Pictures
# 1506          Overture Films
# 214                Universal
# Name: Distributor, dtype: object

# %%
top_n = movies.Distributor.value_counts().index[:6]
top_n
# Out:
# Index(['Warner Bros.', 'Sony Pictures', 'Paramount Pictures', 'Universal',
#        'Walt Disney Pictures', '20th Century Fox'],
#       dtype='object')

# %%
movies.assign(
    Distributor = movies.Distributor.where(
        movies.Distributor.isin(top_n), 'Other'
    )
).Distributor.value_counts()

## movies.Distributor.where() --> only change the value if cond is False
# Out:
# Other                   1604
# Warner Bros.             318
# Sony Pictures            307
# Paramount Pictures       257
# Universal                254
# Walt Disney Pictures     232
# 20th Century Fox         229
# Name: Distributor, dtype: int64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 8))

movies.assign(
    Distributor = movies.Distributor.where(
        movies.Distributor.isin(top_n), 'Other'
    )
).Distributor.value_counts()\
 .plot.bar(ax=ax)
# Out:
# <Axes: >

# %%
# use seaborn
import seaborn as sns
fig, ax = plt.subplots(figsize=(10, 8))
sns.countplot(
    y='Distributor',
    data=(
        movies.assign(
            Distributor = movies.Distributor.where(
                movies.Distributor.isin(top_n), 'Other'
            )
        )
    )
)
# Out:
# <Axes: xlabel='count', ylabel='Distributor'>

# %% [markdown]
# ## Missing values

# %%
movies[movies.MPAA_Rating.isna()]
# Out:
#                                                 Title     US_Gross  \
# 2                          I Married a Strange Person     203134.0
# 3                                Let's Talk About Sex     373615.0
# 5                                 Mississippi Mermaid      24551.0
# 9                                     Duel in the Sun   20400000.0
# 10                                          Tom Jones   37600000.0
# ...                                               ...          ...
# 2945                 Joheunnom nabbeunnom isanghannom     128486.0
# 2967  The Adventures of Tintin: Secret of the Unicorn          0.0
# 3085                            Kurtlar vadisi - Irak          0.0
# 3175                               The Exploding Girl      25572.0
# 3176                                  The Expendables  101384023.0
#
#       Worldwide_Gross  US_DVD_Sales  Production_Budget Release_Date  \
# 2            203134.0           NaN           250000.0  Aug 28 1998
# 3            373615.0           NaN           300000.0  Sep 11 1998
# 5           2624551.0           NaN          1600000.0  Jan 15 1999
# 9          20400000.0           NaN          6000000.0  Dec 31 2046
# 10         37600000.0           NaN          1000000.0  Oct 07 1963
# ...               ...           ...                ...          ...
# 2945       42226657.0           NaN         10000000.0  Apr 23 2010
# 2967              0.0           NaN        130000000.0  Dec 23 2011
# 3085       24906717.0           NaN          8300000.0  Nov 24 2006
# 3175          25572.0           NaN            40000.0  Mar 12 2010
# 3176      240484023.0           NaN         82000000.0  Aug 13 2010
#
#      MPAA_Rating  Running_Time_min            Distributor  \
# 2           None               NaN              Lionsgate
# 3           None               NaN              Fine Line
# 5           None               NaN                    MGM
# 9           None               NaN                   None
# 10          None               NaN                   None
# ...          ...               ...                    ...
# 2945        None               NaN                   None
# 2967        None               NaN     Paramount Pictures
# 3085        None               NaN                   None
# 3175        None              79.0  Oscilloscope Pictures
# 3176        None             103.0              Lionsgate
#
#                             Source Major_Genre         Creative_Type  \
# 2                             None      Comedy                  None
# 3                             None      Comedy                  None
# 5                             None        None                  None
# 9                             None        None                  None
# 10                            None        None                  None
# ...                            ...         ...                   ...
# 2945           Original Screenplay      Action    Historical Fiction
# 2967  Based on Comic/Graphic Novel   Adventure  Contemporary Fiction
# 3085           Original Screenplay      Action  Contemporary Fiction
# 3175                          None        None                  None
# 3176           Original Screenplay      Action  Contemporary Fiction
#
#                 Director  Rotten_Tomatoes_Rating  IMDB_Rating  IMDB_Votes  \
# 2                   None                     NaN          6.8       865.0
# 3                   None                    13.0          NaN         NaN
# 5                   None                     NaN          NaN         NaN
# 9                   None                    86.0          7.0      2906.0
# 10                  None                    81.0          7.0      4035.0
# ...                  ...                     ...          ...         ...
# 2945                None                     NaN          7.4      5548.0
# 2967    Steven Spielberg                     NaN          NaN         NaN
# 3085                None                     NaN          5.7      7936.0
# 3175   Bradley Rust Grey                     NaN          6.2       260.0
# 3176  Sylvester Stallone                    40.0          7.1     42427.0
#
#      Release_Year
# 2            1998
# 3            1998
# 5            1999
# 9            2046
# 10           1963
# ...           ...
# 2945         2010
# 2967         2011
# 3085         2006
# 3175         2010
# 3176         2010
#
# [605 rows x 17 columns]

# %%
movies.MPAA_Rating.value_counts(dropna=False)
# Out:
# R            1194
# PG-13         865
# None          605
# PG            354
# Not Rated      94
# G              79
# NC-17           8
# Open            2
# Name: MPAA_Rating, dtype: int64

# %% [markdown]
# ## applymap, pipe

# %% [markdown]
# - apply
#   - input : 시리즈 원소 / 시리즈 객체 (데이터프레임의 행/열)
#   - return : 단일 값, 시리즈
# - applymap
#   - input : 데이터프레임 원소
#   - return : 동일 형태의 데이터프레임
# - pipe
#   - input : 데이터프레임 객체
#   - return : 단일 값, 시리즈, 데이터프레임

# %%
df = sns.load_dataset('titanic')
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
def count_missing(vec):
  bool_df = vec.isnull()
  sum_df = np.sum(bool_df)
  return sum_df

# %%
df.apply(count_missing)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.pipe(count_missing)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## Comparing continuous values across categories

# %%
mask = movies.MPAA_Rating.isin(
    ['R', 'PG', 'PG-13', 'G']
)

# %%
movies[mask].groupby('MPAA_Rating').Production_Budget.agg(
    ['mean', 'std']
)
# Out:
#                      mean           std
# MPAA_Rating
# G            5.021363e+07  4.293636e+07
# PG           4.622271e+07  4.276483e+07
# PG-13        4.728735e+07  4.376463e+07
# R            2.494916e+07  2.574808e+07

# %%
g = sns.catplot(
    x='MPAA_Rating', y='Production_Budget', data=movies[mask], kind='box'
)

# %% [markdown]
# box plot does not reveal how many samples are in each MPAA_Rating.

# %%
movies[mask].groupby('MPAA_Rating').Production_Budget.count()
# Out:
# MPAA_Rating
# G          79
# PG        354
# PG-13     864
# R        1194
# Name: Production_Budget, dtype: int64

# %%
# another option : swarm plot on top of the box plot
g = sns.catplot(
    x='MPAA_Rating', y='Production_Budget', data=movies[mask], kind='box'
)

sns.swarmplot(
    x='MPAA_Rating',
    y='Production_Budget',
    data=movies[mask],
    color='k',
    size=1,
    ax=g.ax
)
# Out:
# <Axes: xlabel='MPAA_Rating', ylabel='Production_Budget'>

# %%
# catplot usages
g = sns.catplot(
    x = 'MPAA_Rating',
    y = 'Production_Budget',
    data = movies[mask],
    kind = 'box',
    col = 'Release_Year',
    col_order = ['2002', '2004', '2005', '2006'],
    col_wrap=2
)

# %%
g = sns.catplot(
    x='MPAA_Rating',
    y='Production_Budget',
    data=movies[mask],
    kind='box',
    hue='Release_Year',
    hue_order=['2002', '2004', '2005', '2006']
)

# %%
movies[mask]\
.groupby('MPAA_Rating')\
.Production_Budget.agg(['mean', 'std']).astype(int)\
.style.background_gradient(cmap='RdBu', axis=0)
# Out:
# <style type="text/css">
# #T_9821a_row0_col0, #T_9821a_row2_col1 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_9821a_row0_col1 {
#   background-color: #114781;
#   color: #f1f1f1;
# }
# #T_9821a_row1_col0 {
#   background-color: #3480b9;
#   color: #f1f1f1;
# }
# #T_9821a_row1_col1 {
#   background-color: #144e8a;
#   color: #f1f1f1;
# }
# #T_9821a_row2_col0 {
#   background-color: #266caf;
#   color: #f1f1f1;
# }
# #T_9821a_row3_col0, #T_9821a_row3_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9821a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9821a_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_9821a_level0_col1" class="col_heading level0 col1" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >MPAA_Rating</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9821a_level0_row0" class="row_heading level0 row0" >G</th>
#       <td id="T_9821a_row0_col0" class="data row0 col0" >50213632</td>
#       <td id="T_9821a_row0_col1" class="data row0 col1" >42936359</td>
#     </tr>
#     <tr>
#       <th id="T_9821a_level0_row1" class="row_heading level0 row1" >PG</th>
#       <td id="T_9821a_row1_col0" class="data row1 col0" >46222714</td>
#       <td id="T_9821a_row1_col1" class="data row1 col1" >42764831</td>
#     </tr>
#     <tr>
#       <th id="T_9821a_level0_row2" class="row_heading level0 row2" >PG-13</th>
#       <td id="T_9821a_row2_col0" class="data row2 col0" >47287352</td>
#       <td id="T_9821a_row2_col1" class="data row2 col1" >43764633</td>
#     </tr>
#     <tr>
#       <th id="T_9821a_level0_row3" class="row_heading level0 row3" >R</th>
#       <td id="T_9821a_row3_col0" class="data row3 col0" >24949160</td>
#       <td id="T_9821a_row3_col1" class="data row3 col1" >25748082</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Comparing two continuous columns

# %%
# look at the covariance, if they are on the same scale
movies.Production_Budget.cov(movies.US_Gross)
# Out:
# 1389055813372839.5

# %%
# pearson correlation
movies.Production_Budget.corr(movies.US_Gross)
# Out:
# 0.6235663735557185

# %%
# visualize the correlations
fig, ax = plt.subplots(figsize=(8, 8))
corr = movies[['Production_Budget', 'US_Gross', 'Worldwide_Gross']].corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(
    corr,
    mask=mask,
    fmt='.2f',
    annot=True,
    ax=ax,
    cmap='RdBu',
    vmin=-1,
    vmax=1,
    square=True
)
# Out:
# <ipython-input-56-be337597bc88>:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
# <Axes: >

# %%
# use scatterplot
fig, ax = plt.subplots(figsize=(8, 8))
movies.plot.scatter(
    x='Production_Budget', y='US_Gross', alpha=0.1, ax=ax
)
# Out:
# <Axes: xlabel='Production_Budget', ylabel='US_Gross'>

# %%
# seaborn regression
res = sns.lmplot(
    x='Production_Budget', y='US_Gross', data=movies
)

# %% [markdown]
# ## Comparing categorical values with categorical values

# %%
def generalize(ser, match_name, default):
  seen = None
  for match, name in match_name:
    mask = ser.str.contains(match)
    if seen is None:
      seen = Mask
    else:
      seen |= mask
    ser = ser.where(~mask, name)
  ser = ser.where(seen, default)
  return ser

# %%
dists = movies.Distributor.value_counts().index[:6]

# %%
movies.Distributor.where(movies.Distributor.isin(dists), 'Other')
# Out:
# 0                    Other
# 1                    Other
# 2                    Other
# 3                    Other
# 4                    Other
#                ...
# 3196                 Other
# 3197    Paramount Pictures
# 3198         Sony Pictures
# 3199         Sony Pictures
# 3200         Sony Pictures
# Name: Distributor, Length: 3201, dtype: object

# %%
# Cramer's V measure
def cramers_v(x, y):
  confusion_matrix = pd.crosstab(x, y)
  chi2 = ss.chi2_contingency(confusion_matrix)[0]
  n = confusion_matrix.sum().sum()
  phi2 = chi2 / n
  r, k = confusion_matrix.shape
  phi2corr = max(
      0, phi2 - ((k - 1) * (r - 1)) / (n - 1)
  )
  rcorr = r - ((r - 1) ** 2) / (n - 1)
  kcorr = k - ((k - 1) ** 2) / (n - 1)
  return np.sqrt(
      phi2corr / min((kcorr - 1), rcorr - 1)
  )

# %% [markdown]
# ## .size(), .unstack(), .stack()

# %% [markdown]
# ## Pandas Profiling

# %%
import pandas_profiling as pp
pp.ProfileReport(movies)

# %% [markdown]
# ## Selecting data with both integers and labels

# %%
col_start = movies.columns.get_loc('Production_Budget')
col_end = movies.columns.get_loc('MPAA_Rating') + 1

col_start, col_end
# Out:
# (4, 7)

# %%
movies.iloc[:3, col_start:col_end]
# Out:
#    Production_Budget Release_Date MPAA_Rating
# 0          8000000.0  Jun 12 1998           R
# 1           300000.0  Aug 07 1998           R
# 2           250000.0  Aug 28 1998        None

# %%
row_start = movies.index[0]
row_end = movies.index[2]
movies.loc[row_start:row_end, 'Production_Budget':'MPAA_Rating']
# Out:
#    Production_Budget Release_Date MPAA_Rating
# 0          8000000.0  Jun 12 1998           R
# 1           300000.0  Aug 07 1998           R
# 2           250000.0  Aug 28 1998        None

# %% [markdown]
# ## Calculating boolean statistics

# %%
votes_15t = movies['IMDB_Votes'] > 15000
votes_15t
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3196     True
# 3197    False
# 3198    False
# 3199     True
# 3200    False
# Name: IMDB_Votes, Length: 3201, dtype: bool

# %%
votes_15t.sum()
# Out:
# 1497

# %%
votes_15t.mean() * 100
# Out:
# 46.76663542642924

# %%
# greater than
movies['IMDB_Votes'].dropna().gt(15000).mean() * 100
# Out:
# 50.100401606425706

# %%
votes_15t.value_counts(normalize=True)
# Out:
# False    0.532334
# True     0.467666
# Name: IMDB_Votes, dtype: float64

# %% [markdown]
# ## Constructing multiple boolean conditions

# %%
crit1 = movies.IMDB_Rating > 8
crit2 = movies.MPAA_Rating == "PG-13"
crit3 = (movies.Release_Year.astype(int) > 1990) & (movies.Release_Year.astype(int) <= 2022)

# %%
crit_final = crit1 & crit2 & crit3

# %%
crit_final.mean()
# Out:
# 0.005935645110902843

# %%
movies[crit_final].head(3)
# Out:
#              Title     US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 340   Forrest Gump  329694499.0     6.794005e+08           NaN
# 1125     Aeon Flux   25857987.0     4.795334e+07    21927972.0
# 1234        Avatar  760167650.0     2.767891e+09   146153933.0
#
#       Production_Budget Release_Date MPAA_Rating  Running_Time_min  \
# 340          55000000.0  Jul 06 1994       PG-13               NaN
# 1125         55000000.0  Dec 02 2005       PG-13              88.0
# 1234        237000000.0  Dec 18 2009       PG-13               NaN
#
#              Distributor                     Source Major_Genre  \
# 340   Paramount Pictures  Based on Book/Short Story       Drama
# 1125  Paramount Pictures                Based on TV      Action
# 1234    20th Century Fox        Original Screenplay      Action
#
#            Creative_Type         Director  Rotten_Tomatoes_Rating  \
# 340   Historical Fiction  Robert Zemeckis                    70.0
# 1125     Science Fiction             None                    10.0
# 1234     Science Fiction    James Cameron                    83.0
#
#       IMDB_Rating  IMDB_Votes Release_Year
# 340           8.6    300455.0         1994
# 1125          8.1      1193.0         2005
# 1234          8.3    261439.0         2009

# %% [markdown]
# ## Improving the readability of boolean indexing with the query method

# %%
dists = movies.Distributor.value_counts().index[:3]
dists
# Out:
# Index(['Warner Bros.', 'Sony Pictures', 'Paramount Pictures'], dtype='object')

# %%
select_columns = ['Title', 'US_Gross', 'Production_Budget', 'MPAA_Rating']

# %%
qs = (
    "Distributor in @dists "
    " and MPAA_Rating == 'PG-13' "
    " and 500000 <= Production_Budget <= 5000000"
)

# %%
movies_filtered = movies.query(qs)
movies_filtered
# Out:
#                              Title    US_Gross  Worldwide_Gross  US_DVD_Sales  \
# 223        C'era una volta il West   5321508.0        5321508.0           NaN
# 570                   Major Dundee     14873.0          14873.0           NaN
# 1291  Les Triplettes de Belleville   7301288.0       14440113.0           NaN
# 2407             Not Easily Broken  10572742.0       10572742.0    13828911.0
# 2537                   Pootie Tang   3293258.0        3293258.0           NaN
# 2607                 Riding Giants   2276368.0        3216111.0           NaN
#
#       Production_Budget Release_Date MPAA_Rating  Running_Time_min  \
# 223           5000000.0  May 28 1969       PG-13               NaN
# 570           3800000.0  Apr 07 1965       PG-13               NaN
# 1291          2000000.0  Nov 26 2003       PG-13               NaN
# 2407          5000000.0  Jan 09 2009       PG-13               NaN
# 2537          3500000.0  Jun 29 2001       PG-13               NaN
# 2607          2600000.0  Jul 09 2004       PG-13               NaN
#
#              Distributor                     Source  Major_Genre  \
# 223   Paramount Pictures        Original Screenplay      Western
# 570        Sony Pictures  Based on Book/Short Story      Western
# 1291       Sony Pictures        Original Screenplay      Musical
# 2407       Sony Pictures  Based on Book/Short Story        Drama
# 2537  Paramount Pictures        Original Screenplay       Comedy
# 2607       Sony Pictures  Based on Real Life Events  Documentary
#
#              Creative_Type      Director  Rotten_Tomatoes_Rating  IMDB_Rating  \
# 223     Historical Fiction  Sergio Leone                     NaN          8.8
# 570     Historical Fiction          None                    97.0          6.7
# 1291    Historical Fiction          None                     NaN          7.7
# 2407  Contemporary Fiction     Bill Duke                    35.0          5.2
# 2537  Contemporary Fiction          None                    27.0          4.5
# 2607               Factual          None                    93.0          7.7
#
#       IMDB_Votes Release_Year
# 223      74184.0         1969
# 570       2588.0         1965
# 1291     19761.0         2003
# 2407      1010.0         2009
# 2537      6183.0         2001
# 2607      2193.0         2004

# %%
movies_filtered[select_columns]
# Out:
#                              Title    US_Gross  Production_Budget MPAA_Rating
# 223        C'era una volta il West   5321508.0          5000000.0       PG-13
# 570                   Major Dundee     14873.0          3800000.0       PG-13
# 1291  Les Triplettes de Belleville   7301288.0          2000000.0       PG-13
# 2407             Not Easily Broken  10572742.0          5000000.0       PG-13
# 2537                   Pootie Tang   3293258.0          3500000.0       PG-13
# 2607                 Riding Giants   2276368.0          2600000.0       PG-13

# %%
# more..
qs = "Distributor not in @dists and MPAA_Rating == 'PG-13'"
movies_filtered2 = movies.query(qs)
movies_filtered2[select_columns].head(3)
# Out:
#            Title    US_Gross  Production_Budget MPAA_Rating
# 41     The Abyss  54243125.0         70000000.0       PG-13
# 50     The Alamo   7900000.0         12000000.0       PG-13
# 64  Arnolds Park     23616.0           600000.0       PG-13

# %% [markdown]
# ## Masking DataFrame rows

# %%
c1 = movies['Release_Year'].astype(int) >= 2010
c2 = movies['Release_Year'].isna()
criteria = c1 | c2

# %%
movies.mask(criteria).Release_Year.iloc[5:15]
# Out:
# 5     1999
# 6     1999
# 7     1999
# 8     1986
# 9      NaN
# 10    1963
# 11    1968
# 12    1962
# 13    1970
# 14    1987
# Name: Release_Year, dtype: object

# %% [markdown]
# ## 주성분 분석
#  - 수치형 데이터 추출
#  - 정규화 후 주성분분석

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
iris = pd.DataFrame(iris.data, columns=iris.feature_names)
iris['Class'] = load_iris().target
iris['Class'] = iris['Class'].map({0:'Setosa', 1:'Versicolour', 2:'Virginica'})

# %%
X = iris.drop(columns = 'Class')

# 정규화
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)

pd.DataFrame(X).head()
# Out:
#           0         1         2         3
# 0 -0.900681  1.019004 -1.340227 -1.315444
# 1 -1.143017 -0.131979 -1.340227 -1.315444
# 2 -1.385353  0.328414 -1.397064 -1.315444
# 3 -1.506521  0.098217 -1.283389 -1.315444
# 4 -1.021849  1.249201 -1.340227 -1.315444

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 4)
pca_fit = pca.fit(X)

print('고윳값: ', pca_fit.singular_values_)
print('분산 설명력: ', pca.explained_variance_ratio_)
# Out:
# 고윳값:  [20.92306556 11.7091661   4.69185798  1.76273239]
# 분산 설명력:  [0.72962445 0.22850762 0.03668922 0.00517871]

# %%
# scree plot
import matplotlib.pyplot as plt

plt.title('Scree Plot')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.plot(pca.explained_variance_ratio_, 'o-')
plt.show()

# %%
# 주성분 수를 정하고 다시 수행
pca = PCA(n_components=2)

principalComponents = pca.fit_transform(X)
principal_iris = pd.DataFrame(data = principalComponents,
                              columns = ['pc1', 'pc2'])
principal_iris.head()
# Out:
#         pc1       pc2
# 0 -2.264703  0.480027
# 1 -2.080961 -0.674134
# 2 -2.364229 -0.341908
# 3 -2.299384 -0.597395
# 4 -2.389842  0.646835

# %%
# 산포도 확인
import seaborn as sns

plt.title('2 component PCA')
sns.scatterplot(x = 'pc1', y = 'pc2', hue = iris.Class,
                data = principal_iris)
plt.show()

# %% [markdown]
# ## 언더 샘플링

# %%
from sklearn.datasets import make_classification
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

x, y = make_classification(n_samples=2000, n_features=6, weights=[0.95], flip_y=0)

print(Counter(y))
# Out:
# Counter({0: 1900, 1: 100})

# %%
undersample = RandomUnderSampler(sampling_strategy='majority')
x_under, y_under = undersample.fit_resample(x, y)

print(Counter(y_under))
# Out:
# Counter({0: 100, 1: 100})

# %%
undersample = RandomUnderSampler(sampling_strategy=0.5)
x_under2, y_under2 = undersample.fit_resample(x, y)

print(Counter(y_under2))
# Out:
# Counter({0: 200, 1: 100})

# %% [markdown]
# ## 오버 샘플링

# %%
# Random over sampling
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy=0.5)
x_over, y_over = oversample.fit_resample(x, y)
print(Counter(y_over))
# Out:
# Counter({0: 1900, 1: 950})

# %%
oversample = RandomOverSampler(sampling_strategy='minority')
x_over2, y_over2 = oversample.fit_resample(x, y)
print(Counter(y_over2))
# Out:
# Counter({0: 1900, 1: 1900})

# %%
# SMOTE
### 소수 레이블을 지닌 데이터 세트의 관측 값에 대한 K개의 최근접 이웃을 찾고,
### 관측 값과 이웃으로 선택된 값 사이에 임의의 새로운 데이터를 생성하는 방법으로 샘플의 수를 늘린다.
from imblearn.over_sampling import SMOTE
smote_sample = SMOTE(sampling_strategy='minority')
x_sm, y_sm = smote_sample.fit_resample(x, y)
print(Counter(y_sm))
# Out:
# Counter({0: 1900, 1: 1900})

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))
sns.scatterplot(x=x[:, 1], y=x[:, 2], hue=y, ax=axes[0][0], alpha=0.5)
sns.scatterplot(x=x_under[:, 1], y=x_under[:, 2], hue=y_under, ax=axes[0][1], alpha=0.5)
sns.scatterplot(x=x_over[:, 1], y=x_over[:, 2], hue=y_over, ax=axes[1][0], alpha=0.5)
sns.scatterplot(x=x_sm[:, 1], y=x_sm[:, 2], hue=y_sm, ax=axes[1][1], alpha=0.5)

axes[0][0].set_title('Original Data')
axes[0][1].set_title('Random Under Sampling')
axes[1][0].set_title('Random Over Sampling')
axes[1][1].set_title('SMOTE')

plt.show()

# %% [markdown]
# ## 머신러닝 분석 프로세스
#
# 1. 데이터 확인
#   - 독립/종속변수 확인
#   - 연속형/범주형 확인
#   - 적용 가능한 분석모델 확인
# 2. 데이터 분할
# 3. 전처리
#   - 표준화/정규화
#   - 결측치 확인 후 처리
#   - 이상치 확인 후 처리
# 4. 모델 학습
#   - 머신러닝 알고리즘 적용
#   - 회귀/분류/비지도 학습
#   - 하이퍼파라미터 조절
# 5. 성능평가

# %% [markdown]
# ## 회귀분석 맛보기

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
boston = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
boston_dt = np.hstack([boston.values[::2, :], boston.values[1::2, :2]])
price = boston.values[1::2, 2]


df = pd.DataFrame(boston_dt, columns=[
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PIRATIO', 'B', 'LSTAT'
    ])
df['PRICE'] = price

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PIRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PIRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PIRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %%
# regplot은 산점도와 회귀직선을 동시에 나타냄
# constrained_layout = True 이면 그래프 사이의 적절한 간격을 자동으로 설정

fig, axs = plt.subplots(figsize=(16,10), ncols=4, nrows=3, constrained_layout=True)
features = df.columns.difference(['PRICE', 'CHAS'])

for i, feature in zip(range(12), features):
  row = int(i/4)
  col = i%4

  sns.regplot(x=feature, y=df['PRICE'], data=df, ax=axs[row][col])

# %%
# 데이터 분할
from sklearn.model_selection import train_test_split

x = df[['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PIRATIO', 'B', 'LSTAT']].values
y = df['PRICE'].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print('학습데이터세트 PRICE 평균: ', y_train.mean())
print('평가데이터세트 PRICE 평균: ', y_test.mean())
# Out:
# 학습데이터세트 PRICE 평균:  22.796534653465343
# 평가데이터세트 PRICE 평균:  21.488235294117644

# %%
# 전처리
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)

# %%
# 모델 학습
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

pred_train = linear.predict(x_train_scaled)

mae = mean_absolute_error(y_train, pred_train)
mse = mean_squared_error(y_train, pred_train)
rmse = np.sqrt(mse)
r2 = r2_score(y_train, pred_train)

print('MAE: {0: .5f}'.format(mae))
print('MSE: {0: .5f}'.format(mse))
print('RMSE: {0: .5f}'.format(rmse))
print('R2: {0: .5f}'.format(r2))
# Out:
# MAE:  3.32616
# MSE:  22.11246
# RMSE:  4.70239
# R2:  0.74546

# %%
# 성능평가 및 예측값 저장
x_test_scaled = scaler.transform(x_test)
pred = linear.predict(x_test_scaled)

# %%
mae = mean_absolute_error(y_test, pred)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)

print('MAE: {0: .5f}'.format(mae))
print('MSE: {0: .5f}'.format(mse))
print('RMSE: {0: .5f}'.format(rmse))
print('R2: {0: .5f}'.format(r2))
# Out:
# MAE:  3.23724
# MSE:  24.63539
# RMSE:  4.96341
# R2:  0.66406

# %%
pred_df = pd.DataFrame(pred, columns=['pred Price'])
pred_df.head()
# Out:
#    pred Price
# 0   29.218660
# 1   33.551467
# 2   14.810658
# 3   25.084725
# 4   19.173927

# %%
actual = pd.DataFrame(y_test, columns=['actual Price'])
actual.head()
# Out:
#    actual Price
# 0          23.6
# 1          32.4
# 2          13.6
# 3          22.8
# 4          16.1

# %%
reg_result = pd.concat([actual, pred_df], axis=1)
reg_result.head()
# Out:
#    actual Price  pred Price
# 0          23.6   29.218660
# 1          32.4   33.551467
# 2          13.6   14.810658
# 3          22.8   25.084725
# 4          16.1   19.173927

# %% [markdown]
# ## 분류분석 맛보기

# %%
from sklearn.datasets import load_iris

iris = load_iris()
iris_dt = iris.data
iris_label = iris.target

df = pd.DataFrame(data=iris_dt, columns=iris.feature_names)
df['Species'] = iris_label

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
df.shape
# Out:
# (150, 5)

# %%
# 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(
    iris_dt, iris_label, test_size=0.2, random_state=0, stratify=iris_label
)

# %%
# 전처리
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Species              0
# dtype: int64

# %%
# 모델 학습
from sklearn.tree import DecisionTreeClassifier
dtree_clf_5 = DecisionTreeClassifier(max_depth=5, random_state=100)
dtree_clf_3 = DecisionTreeClassifier(max_depth=3, random_state=100)
dtree_clf_1 = DecisionTreeClassifier(max_depth=1, random_state=100)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(dtree_clf_5, x_train, y_train, scoring='accuracy', cv=10)

print('교차검증 정확도: ', np.round(scores, 3))
print('평균 검증 정확도: ', np.round(np.mean(scores), 4))
# Out:
# 교차검증 정확도:  [0.917 1.    0.917 1.    1.    0.833 1.    0.917 1.    0.833]
# 평균 검증 정확도:  0.9417

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(dtree_clf_3, x_train, y_train, scoring='accuracy', cv=10)

print('교차검증 정확도: ', np.round(scores, 3))
print('평균 검증 정확도: ', np.round(np.mean(scores), 4))
# Out:
# 교차검증 정확도:  [0.917 1.    0.917 0.917 1.    0.833 1.    0.917 0.917 0.833]
# 평균 검증 정확도:  0.925

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(dtree_clf_1, x_train, y_train, scoring='accuracy', cv=10)

print('교차검증 정확도: ', np.round(scores, 3))
print('평균 검증 정확도: ', np.round(np.mean(scores), 4))
# Out:
# 교차검증 정확도:  [0.667 0.667 0.667 0.667 0.667 0.667 0.667 0.667 0.667 0.667]
# 평균 검증 정확도:  0.6667

# %%
# 성능평가 및 예측값 저장
dtree_clf_5.fit(x_train, y_train)
pred = dtree_clf_5.predict(x_test)

from sklearn.metrics import accuracy_score
print('의사결정나무(교차검증 후) 예측 정확도: {0:.5f}'.format(accuracy_score(y_test, pred)))
# Out:
# 의사결정나무(교차검증 후) 예측 정확도: 0.96667

# %%
pred = pd.DataFrame(pred, columns=['pred Species'])
pred.head()
# Out:
#    pred Species
# 0             0
# 1             1
# 2             0
# 3             2
# 4             0

# %%
actual = pd.DataFrame(y_test, columns=['actual Species'])
actual.head()
# Out:
#    actual Species
# 0               0
# 1               1
# 2               0
# 3               2
# 4               0

# %%
classify_result = pd.concat([actual, pred], axis=1)
classify_result.head()
# Out:
#    actual Species  pred Species
# 0               0             0
# 1               1             1
# 2               0             0
# 3               2             2
# 4               0             0

# %% [markdown]
# ## 단순 선형 회귀

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns

data = sns.load_dataset('diamonds')

# %%
data.head(3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
x = data['carat']
y = data['price']

plt.figure(figsize=(10,5))
plt.scatter(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
x = np.array(data['carat'])
y = np.array(data['price'])

# %%
x = x.reshape(53940,1)
y = y.reshape(53940,1)

# %%
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.intercept_, lr.coef_
# Out:
# (array([-2256.36058005]), array([[7756.42561797]]))

# %%
lr.score(x,y)
# Out:
# 0.8493305264354858

# %% [markdown]
# ## 경사 하강법

# %%
from sklearn.linear_model import SGDRegressor

sgd_reg = SGDRegressor(max_iter=1000, random_state=34)
sgd_reg.fit(x,y.ravel())
# Out:
# SGDRegressor(random_state=34)

# %%
sgd_reg.intercept_, sgd_reg.coef_
# Out:
# (array([-2244.58664356]), array([7778.78854515]))

# %% [markdown]
# ## 릿지 회귀

# %%
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()
x = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
y = diabetes.target

# %%
from sklearn.linear_model import Ridge

alpha = np.logspace(-3, 1, 5)

data = []
for i, a in enumerate(alpha):
  ridge = Ridge(alpha=a)
  ridge.fit(x, y)
  data.append(pd.Series(np.hstack([ridge.coef_])))

df_ridge = pd.DataFrame(data, index=alpha)
df_ridge.columns = x.columns
df_ridge
# Out:
#               age         sex         bmi          bp          s1          s2  \
# 0.001   -9.549162 -239.086958  520.369375  323.822745 -712.322159  413.379125
# 0.010   -7.197534 -234.549764  520.588601  320.517131 -380.607135  150.484671
# 0.100    1.308705 -207.192418  489.695171  301.764058  -83.466034  -70.826832
# 1.000   29.466112  -83.154276  306.352680  201.627734    5.909614  -29.515495
# 10.000  19.812842   -0.918430   75.416214   55.025160   19.924621   13.948715
#
#                 s3          s4          s5          s6
# 0.001    65.811323  167.513007  720.939924   68.123360
# 0.010   -78.589275  130.312521  592.347959   71.134844
# 0.100  -188.678898  115.712136  443.812917   86.749315
# 1.000  -152.040280  117.311732  262.944290  111.878956
# 10.000  -47.553816   48.259433   70.143948   44.213892

# %%
ridge.coef_
# Out:
# array([ 19.81284181,  -0.91842974,  75.41621398,  55.02515953,
#         19.92462111,  13.94871542, -47.5538158 ,  48.2594332 ,
#         70.14394833,  44.21389238])

# %%
np.hstack([ridge.coef_])
# Out:
# array([ 19.81284181,  -0.91842974,  75.41621398,  55.02515953,
#         19.92462111,  13.94871542, -47.5538158 ,  48.2594332 ,
#         70.14394833,  44.21389238])

# %%
np.hstack(ridge.coef_)
# Out:
# array([ 19.81284181,  -0.91842974,  75.41621398,  55.02515953,
#         19.92462111,  13.94871542, -47.5538158 ,  48.2594332 ,
#         70.14394833,  44.21389238])
