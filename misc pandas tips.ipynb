# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
# highlight max/min value of each column
df.groupby('class').agg('mean')\
  .style\
  .highlight_max(axis=0, color='pink')\
  .highlight_min(axis=0, color='lightgreen')
# Out:
# <ipython-input-5-da21278172cd>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('class').agg('mean')\
# <style type="text/css">
# #T_127b5_row0_col0, #T_127b5_row0_col2, #T_127b5_row0_col5, #T_127b5_row2_col1, #T_127b5_row2_col3, #T_127b5_row2_col4, #T_127b5_row2_col6, #T_127b5_row2_col7 {
#   background-color: pink;
# }
# #T_127b5_row0_col1, #T_127b5_row0_col4, #T_127b5_row0_col7, #T_127b5_row1_col3, #T_127b5_row1_col6, #T_127b5_row2_col0, #T_127b5_row2_col2, #T_127b5_row2_col5 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_127b5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_127b5_level0_col0" class="col_heading level0 col0" >survived</th>
# ...
